# %%
import pandas as pd
from lets_plot import*
LetsPlot.setup_html()
import numpy as np
# Out:
#         <div id="unTicq"></div>
#         <script type="text/javascript" data-lets-plot-script="library">
#             if(!window.letsPlotCallQueue) {
#                 window.letsPlotCallQueue = [];
#             };
#             window.letsPlotCall = function(f) {
#                 window.letsPlotCallQueue.push(f);
#             };
#             (function() {
#                 var script = document.createElement("script");
#                 script.type = "text/javascript";
#                 script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.8.1/js-package/distr/lets-plot.min.js";
#                 script.onload = function() {
#                     window.letsPlotCall = function(f) {f();};
#                     window.letsPlotCallQueue.forEach(function(f) {f();});
#                     window.letsPlotCallQueue = [];
#
#                 };
#                 script.onerror = function(event) {
#                     window.letsPlotCall = function(f) {};    // noop
#                     window.letsPlotCallQueue = [];
#                     var div = document.createElement("div");
#                     div.style.color = 'darkred';
#                     div.textContent = 'Error loading Lets-Plot JS';
#                     document.getElementById("unTicq").appendChild(div);
#                 };
#                 var e = document.getElementById("unTicq");
#                 e.appendChild(script);
#             })()
#         </script>

# %%
import os

# %%
all_files = [os.path.join('../data/waitrose', file) for file in os.listdir('../data/waitrose') 
             if file.endswith('.csv')]
df=pd.concat((pd.read_csv(file) for file in all_files))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25418 entries, 0 to 1593
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   data-product-id        25418 non-null  int64
#  1   data-product-name      25418 non-null  object
#  2   data-product-type      25418 non-null  object
#  3   data-product-on-offer  25418 non-null  bool
#  4   data-product-index     25408 non-null  float64
#  5   image-url              25418 non-null  object
#  6   product-page           25418 non-null  object
#  7   product-name           25407 non-null  object
#  8   product-size           25363 non-null  object
#  9   item-price             25407 non-null  object
#  10  price-per-unit         24976 non-null  object
#  11  offer-description      7201 non-null   object
#  12  category               25418 non-null  object
# dtypes: bool(1), float64(1), int64(1), object(10)
# memory usage: 2.5+ MB

# %%
all_files
# Out:
# ['../data/waitrose\\baby-child-and-parent.csv',
#  '../data/waitrose\\bakery.csv',
#  '../data/waitrose\\beer-wine-and-spirits.csv',
#  '../data/waitrose\\best-of-british.csv',
#  '../data/waitrose\\dietary-and-lifestyle.csv',
#  '../data/waitrose\\everyday-value.csv',
#  '../data/waitrose\\food-cupboard.csv',
#  '../data/waitrose\\fresh-and-chilled.csv',
#  '../data/waitrose\\frozen.csv',
#  '../data/waitrose\\home.csv',
#  '../data/waitrose\\household.csv',
#  '../data/waitrose\\new.csv',
#  '../data/waitrose\\organic-shop.csv',
#  '../data/waitrose\\pet.csv',
#  '../data/waitrose\\summer.csv',
#  '../data/waitrose\\tea-coffee-and-soft-drinks.csv',
#  '../data/waitrose\\toiletries-health-and-beauty.csv',
#  '../data/waitrose\\waitrose-brands.csv']

# %%
df.head()
# Out:
#    data-product-id                         data-product-name  \
# 0           525635  Organix Raspberry & Apple Soft Oaty Bars
# 1           557746             Organix Carrot Cake Oaty Bars
# 2            32062                  Aptamil 2 Follow On Milk
# 3           767801                      Essential Baby Wipes
# 4           514054                  Organix Apple Rice Cakes
#
#   data-product-type  data-product-on-offer  data-product-index  \
# 0                 G                  False                 1.0
# 1                 G                  False                 2.0
# 2                 G                  False               394.0
# 3                 G                  False                 4.0
# 4                 G                  False                 5.0
#
#                                            image-url  \
# 0  https://ecom-su-static-prod.wtrecom.com/images...
# 1  https://ecom-su-static-prod.wtrecom.com/images...
# 2  https://ecom-su-static-prod.wtrecom.com/images...
# 3  https://ecom-su-static-prod.wtrecom.com/images...
# 4  https://ecom-su-static-prod.wtrecom.com/images...
#
#                                         product-page  \
# 0  https://www.waitrose.com/ecom/products/organix...
# 1  https://www.waitrose.com/ecom/products/organix...
# 2  https://www.waitrose.com/ecom/products/aptamil...
# 3  https://www.waitrose.com/ecom/products/essenti...
# 4  https://www.waitrose.com/ecom/products/organix...
#
#                                product-name product-size item-price  \
# 0  Organix Raspberry & Apple Soft Oaty Bars        6x23g      £3.15
# 1             Organix Carrot Cake Oaty Bars        6x23g      £3.15
# 2                  Aptamil 2 Follow On Milk         800g     £13.50
# 3                      Essential Baby Wipes          80s        95p
# 4                  Organix Apple Rice Cakes          40g      £1.60
#
#   price-per-unit offer-description              category
# 0     £2.29/100g               NaN  Baby, Child & Parent
# 1     £2.29/100g               NaN  Baby, Child & Parent
# 2      £16.88/kg               NaN  Baby, Child & Parent
# 3      1.2p each               NaN  Baby, Child & Parent
# 4        £4/100g               NaN  Baby, Child & Parent

# %%
df.tail()
# Out:
#       data-product-id                                  data-product-name  \
# 1589            18427                Duchy Organic British Lamb Half Leg
# 1590            11606                         Cooks' Ingredients Wok Oil
# 1591             6903  No. 1 Badoz Vacherin Du Haut-Doubs AOP French ...
# 1592             6125                  Cooks' Ingredients White Marzipan
# 1593           707668              Duchy Organic Pinot Grigio Bag in Box
#
#      data-product-type  data-product-on-offer  data-product-index  \
# 1589                 G                  False              1590.0
# 1590                 G                  False              1591.0
# 1591                 G                  False              1592.0
# 1592                 G                  False              1593.0
# 1593                 W                  False              1594.0
#
#                                               image-url  \
# 1589  https://ecom-su-static-prod.wtrecom.com/images...
# 1590  https://ecom-su-static-prod.wtrecom.com/images...
# 1591  https://ecom-su-static-prod.wtrecom.com/images...
# 1592  https://ecom-su-static-prod.wtrecom.com/images...
# 1593  https://ecom-su-static-prod.wtrecom.com/images...
#
#                                            product-page  \
# 1589  https://www.waitrose.com/ecom/products/duchy-o...
# 1590  https://www.waitrose.com/ecom/products/cooks-i...
# 1591  https://www.waitrose.com/ecom/products/no-1-ba...
# 1592  https://www.waitrose.com/ecom/products/cooks-i...
# 1593  https://www.waitrose.com/ecom/products/duchy-o...
#
#                                            product-name  \
# 1589                Duchy Organic British Lamb Half Leg
# 1590                         Cooks' Ingredients Wok Oil
# 1591  No. 1 Badoz Vacherin Du Haut-Doubs AOP French ...
# 1592                  Cooks' Ingredients White Marzipan
# 1593              Duchy Organic Pinot Grigio Bag in Box
#
#                product-size        item-price price-per-unit  \
# 1589  Typical weight 0.94kg  £24.31 each est.      £26.00/kg
# 1590                  250ml             £2.40      96p/100ml
# 1591                   350g            £10.00      £28.58/kg
# 1592                   500g             £2.50          £5/kg
# 1593                  2.25L            £21.49     £7.17/75cl
#
#      offer-description         category
# 1589               NaN  Waitrose Brands
# 1590               NaN  Waitrose Brands
# 1591               NaN  Waitrose Brands
# 1592               NaN  Waitrose Brands
# 1593               NaN  Waitrose Brands

# %%
# Drop duplicates
df = df.drop_duplicates()

df = df.drop(columns=['data-product-name', 
                      'data-product-type', 
                      'data-product-index'])
df = (
    df.rename(columns={
        'data-product-id': 'id',
        'data-product-on-offer': 'offer',
        'product-page': 'page',
        'product-name': 'name',
        'product-size': 'size',
    })
)

# The id does not need 64 bits. 32 bits is enough.
# See https://numpy.org/doc/stable/reference/arrays.scalars.html#numpy.intc for ranges.
df['id'] = df['id'].astype('int32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25378 entries, 0 to 1593
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 25378 non-null  int32
#  1   offer              25378 non-null  bool
#  2   image-url          25378 non-null  object
#  3   page               25378 non-null  object
#  4   name               25367 non-null  object
#  5   size               25323 non-null  object
#  6   item-price         25367 non-null  object
#  7   price-per-unit     24936 non-null  object
#  8   offer-description  7178 non-null   object
#  9   category           25378 non-null  object
# dtypes: bool(1), int32(1), object(8)
# memory usage: 1.9+ MB

# %%
def clean_item_price(item_price: str):
    if'each est' in item_price:
        item_price=item_price.replace("each est.","")
    if type(item_price)!=str:
        pass    
    if '£' in item_price:
        item_price = item_price.replace('£', '')
    elif 'p' in item_price:
        item_price = item_price.replace('p', '')
        item_price = '0.' + item_price
    if'-' in item_price:
        item_price=item_price.split('-')[0]    
    return float(item_price)

# %%
df.iloc[0]
# Out:
# id                                                              525635
# offer                                                            False
# image-url            https://ecom-su-static-prod.wtrecom.com/images...
# page                 https://www.waitrose.com/ecom/products/organix...
# name                          Organix Raspberry & Apple Soft Oaty Bars
# size                                                             6x23g
# item-price                                                       £3.15
# price-per-unit                                              £2.29/100g
# offer-description                                                  NaN
# category                                          Baby, Child & Parent
# Name: 0, dtype: object

# %%
df['item-price-fixed'] = df['item-price'].astype(str).apply(clean_item_price)

# %%
df['item-price-fixed']
# Out:
# 0        3.15
# 1        3.15
# 2       13.50
# 3        0.95
# 4        1.60
#         ...
# 1589    24.31
# 1590     2.40
# 1591    10.00
# 1592     2.50
# 1593    21.49
# Name: item-price-fixed, Length: 25378, dtype: float64

# %%
selecter_rows=df['item-price'].astype(str).str.contains('-')
df.loc[selecter_rows,'size']=df.loc[selecter_rows,'size'].str.split('-').str[0].str.replace('(','')

# %%
df["item-price"]=df["item-price-fixed"]
df=df.drop(columns=["item-price-fixed"])

# %%
df[["name","item-price","size"]]
# Out:
#                                                    name  item-price  \
# 0              Organix Raspberry & Apple Soft Oaty Bars        3.15
# 1                         Organix Carrot Cake Oaty Bars        3.15
# 2                              Aptamil 2 Follow On Milk       13.50
# 3                                  Essential Baby Wipes        0.95
# 4                              Organix Apple Rice Cakes        1.60
# ...                                                 ...         ...
# 1589                Duchy Organic British Lamb Half Leg       24.31
# 1590                         Cooks' Ingredients Wok Oil        2.40
# 1591  No. 1 Badoz Vacherin Du Haut-Doubs AOP French ...       10.00
# 1592                  Cooks' Ingredients White Marzipan        2.50
# 1593              Duchy Organic Pinot Grigio Bag in Box       21.49
#
#                        size
# 0                     6x23g
# 1                     6x23g
# 2                      800g
# 3                       80s
# 4                       40g
# ...                     ...
# 1589  Typical weight 0.94kg
# 1590                  250ml
# 1591                   350g
# 1592                   500g
# 1593                  2.25L
#
# [25378 rows x 3 columns]

# %%
df.groupby("category")["item-price"].describe()
# Out:
#                               count       mean        std   min     25%  \
# category
# Baby, Child & Parent          428.0   5.196215   4.677661  0.60  1.8000
# Bakery                        482.0   4.846680   7.750208  0.50  1.6000
# Beer, Wine & Spirits         1679.0  14.425057  15.720801  0.30  5.3700
# Best of British               322.0   6.928106  12.570727  0.10  2.7125
# Dietary & Lifestyle          3337.0   3.795999   4.755322  0.10  1.9500
# Everyday Value                141.0   1.740284   1.202873  0.15  1.1000
# Food Cupboard                4186.0   2.665160   2.138691  0.35  1.6000
# Fresh & Chilled              3578.0   3.815151   5.267549  0.10  2.0000
# Frozen                        431.0   3.627378   1.544523  0.70  2.6500
# Home                         1075.0   8.595033  10.764164  0.49  3.0000
# Household                     927.0   5.518619   3.934800  0.70  2.9500
# New                           803.0   5.300162   4.948709  0.80  2.5000
# Organic Shop                  671.0   4.937928   5.355143  0.60  2.0000
# Pet                           372.0   5.403306   4.381911  0.65  2.2500
# Summer                       1799.0   6.002223   7.900751  0.30  2.5000
# Tea, Coffee & Soft Drinks    1290.0   3.826000   2.743019  0.40  2.1000
# Toiletries, Health & Beauty  2255.0   7.734093   7.883916  0.55  3.1600
# Waitrose Brands              1591.0   3.005475   3.380658  0.10  1.4000
#
#                                50%      75%     max
# category
# Baby, Child & Parent         3.075   7.2625   25.00
# Bakery                       2.200   3.1500   45.00
# Beer, Wine & Spirits         9.990  17.9900  299.99
# Best of British              4.150   6.0000  168.00
# Dietary & Lifestyle          2.750   4.0000  139.99
# Everyday Value               1.350   2.0000    8.00
# Food Cupboard                2.250   3.0000   43.50
# Fresh & Chilled              2.900   4.1425  168.00
# Frozen                       3.500   4.4750   12.00
# Home                         5.990  10.5000  159.00
# Household                    4.500   7.0000   45.00
# New                          3.500   6.0000   33.00
# Organic Shop                 2.950   5.0000   35.00
# Pet                          4.050   7.4500   30.00
# Summer                       3.750   6.0500  168.00
# Tea, Coffee & Soft Drinks    3.500   4.7500   59.99
# Toiletries, Health & Beauty  5.600  10.0000  168.00
# Waitrose Brands              2.100   3.4000   53.20

# %%
plot_df=df.groupby("category")["item-price"].describe().reset_index()

# %%
plot_df
# Out:
#                        category   count       mean        std   min     25%  \
# 0          Baby, Child & Parent   428.0   5.196215   4.677661  0.60  1.8000
# 1                        Bakery   482.0   4.846680   7.750208  0.50  1.6000
# 2          Beer, Wine & Spirits  1679.0  14.425057  15.720801  0.30  5.3700
# 3               Best of British   322.0   6.928106  12.570727  0.10  2.7125
# 4           Dietary & Lifestyle  3337.0   3.795999   4.755322  0.10  1.9500
# 5                Everyday Value   141.0   1.740284   1.202873  0.15  1.1000
# 6                 Food Cupboard  4186.0   2.665160   2.138691  0.35  1.6000
# 7               Fresh & Chilled  3578.0   3.815151   5.267549  0.10  2.0000
# 8                        Frozen   431.0   3.627378   1.544523  0.70  2.6500
# 9                          Home  1075.0   8.595033  10.764164  0.49  3.0000
# 10                    Household   927.0   5.518619   3.934800  0.70  2.9500
# 11                          New   803.0   5.300162   4.948709  0.80  2.5000
# 12                 Organic Shop   671.0   4.937928   5.355143  0.60  2.0000
# 13                          Pet   372.0   5.403306   4.381911  0.65  2.2500
# 14                       Summer  1799.0   6.002223   7.900751  0.30  2.5000
# 15    Tea, Coffee & Soft Drinks  1290.0   3.826000   2.743019  0.40  2.1000
# 16  Toiletries, Health & Beauty  2255.0   7.734093   7.883916  0.55  3.1600
# 17              Waitrose Brands  1591.0   3.005475   3.380658  0.10  1.4000
#
#       50%      75%     max
# 0   3.075   7.2625   25.00
# 1   2.200   3.1500   45.00
# 2   9.990  17.9900  299.99
# 3   4.150   6.0000  168.00
# 4   2.750   4.0000  139.99
# 5   1.350   2.0000    8.00
# 6   2.250   3.0000   43.50
# 7   2.900   4.1425  168.00
# 8   3.500   4.4750   12.00
# 9   5.990  10.5000  159.00
# 10  4.500   7.0000   45.00
# 11  3.500   6.0000   33.00
# 12  2.950   5.0000   35.00
# 13  4.050   7.4500   30.00
# 14  3.750   6.0500  168.00
# 15  3.500   4.7500   59.99
# 16  5.600  10.0000  168.00
# 17  2.100   3.4000   53.20

# %%
plot_df.rename(columns={"25%":"Q1",
                       "50%":"Median",
                       "75%":"Q3"},
                       inplace=True)

# %%
plot_df
# Out:
#                        category   count       mean        std   min      Q1  \
# 0          Baby, Child & Parent   428.0   5.196215   4.677661  0.60  1.8000
# 1                        Bakery   482.0   4.846680   7.750208  0.50  1.6000
# 2          Beer, Wine & Spirits  1679.0  14.425057  15.720801  0.30  5.3700
# 3               Best of British   322.0   6.928106  12.570727  0.10  2.7125
# 4           Dietary & Lifestyle  3337.0   3.795999   4.755322  0.10  1.9500
# 5                Everyday Value   141.0   1.740284   1.202873  0.15  1.1000
# 6                 Food Cupboard  4186.0   2.665160   2.138691  0.35  1.6000
# 7               Fresh & Chilled  3578.0   3.815151   5.267549  0.10  2.0000
# 8                        Frozen   431.0   3.627378   1.544523  0.70  2.6500
# 9                          Home  1075.0   8.595033  10.764164  0.49  3.0000
# 10                    Household   927.0   5.518619   3.934800  0.70  2.9500
# 11                          New   803.0   5.300162   4.948709  0.80  2.5000
# 12                 Organic Shop   671.0   4.937928   5.355143  0.60  2.0000
# 13                          Pet   372.0   5.403306   4.381911  0.65  2.2500
# 14                       Summer  1799.0   6.002223   7.900751  0.30  2.5000
# 15    Tea, Coffee & Soft Drinks  1290.0   3.826000   2.743019  0.40  2.1000
# 16  Toiletries, Health & Beauty  2255.0   7.734093   7.883916  0.55  3.1600
# 17              Waitrose Brands  1591.0   3.005475   3.380658  0.10  1.4000
#
#     Median       Q3     max
# 0    3.075   7.2625   25.00
# 1    2.200   3.1500   45.00
# 2    9.990  17.9900  299.99
# 3    4.150   6.0000  168.00
# 4    2.750   4.0000  139.99
# 5    1.350   2.0000    8.00
# 6    2.250   3.0000   43.50
# 7    2.900   4.1425  168.00
# 8    3.500   4.4750   12.00
# 9    5.990  10.5000  159.00
# 10   4.500   7.0000   45.00
# 11   3.500   6.0000   33.00
# 12   2.950   5.0000   35.00
# 13   4.050   7.4500   30.00
# 14   3.750   6.0500  168.00
# 15   3.500   4.7500   59.99
# 16   5.600  10.0000  168.00
# 17   2.100   3.4000   53.20

# %%
tooltip_setup = (
    layer_tooltips()
        .line('@category')
        .line('[@Q1 -- @Median -- @Q3]')
        .format('@Q1', '£ {.2f}')
        .format('@Median', '£ {.2f}')
        .format('@Q3', '£ {.2f}')
)
g =(
    ggplot(plot_df, aes(y='category', x='Median', xmin='Q1', xmax='Q3', fill='category')) +
    geom_linerange(size=1, alpha=0.75, tooltips=tooltip_setup) +
    geom_point(size=3, stroke=1, shape=21, tooltips=tooltip_setup) +
    scale_fill_discrete(guide='none') +
    scale_y_continuous(name="Categories\n(from largest to smallest median)", expand=[0.05, 0.05]) +
    scale_x_continuous(name="Price (£)", expand=[0., 0.05], format='£ {.2f}', breaks=np.arange(0, 20, 2.5)) +
     labs(title='"Beer, Wine & Spirits" has the highest median price for individual items',
         subtitle="Dots represent the median price, bars represent the 25th and 75th percentiles") +
    theme(axis_text_x=element_text(size=15),
        axis_text_y=element_text(size=17),
        axis_title_x=element_text(size=20),
        axis_title_y=element_text(size=20),
        plot_title=element_text(size=19, face='bold'),
        plot_subtitle=element_text(size=18),
        legend_position='none') +
    ggsize(1000, 500)

)
g
# Out:
#    <div id="yarBDf" ></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("yarBDf");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "category":["Baby, Child & Parent","Bakery","Beer, Wine & Spirits","Best of British","Dietary & Lifestyle","Everyday Value","Food Cupboard","Fresh & Chilled","Frozen","Home","Household","New","Organic Shop","Pet","Summer","Tea, Coffee & Soft Drinks","Toiletries, Health & Beauty","Waitrose Brands"],
# "Q1":[1.8,1.6,5.37,2.7125000000000004,1.95,1.1,1.6,2.0,2.65,3.0,2.95,2.5,2.0,2.25,2.5,2.1,3.16,1.4],
# "Median":[3.075,2.2,9.99,4.15,2.75,1.35,2.25,2.9,3.5,5.99,4.5,3.5,2.95,4.05,3.75,3.5,5.6,2.1],
# "Q3":[7.2625,3.15,17.99,6.0,4.0,2.0,3.0,4.1425,4.475,10.5,7.0,6.0,5.0,7.45,6.05,4.75,10.0,3.4]
# },
# "mapping":{
# "x":"Median",
# "y":"category",
# "xmin":"Q1",
# "xmax":"Q3",
# "fill":"category"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"category"
# },{
# "type":"float",
# "column":"count"
# },{
# "type":"float",
# "column":"mean"
# },{
# "type":"float",
# "column":"std"
# },{
# "type":"float",
# "column":"min"
# },{
# "type":"float",
# "column":"Q1"
# },{
# "type":"float",
# "column":"Median"
# },{
# "type":"float",
# "column":"Q3"
# },{
# "type":"float",
# "column":"max"
# }]
# },
# "ggtitle":{
# "text":"\"Beer, Wine & Spirits\" has the highest median price for individual items",
# "subtitle":"Dots represent the median price, bars represent the 25th and 75th percentiles"
# },
# "theme":{
# "axis_title_x":{
# "size":20.0,
# "blank":false
# },
# "axis_title_y":{
# "size":20.0,
# "blank":false
# },
# "axis_text_x":{
# "size":15.0,
# "blank":false
# },
# "axis_text_y":{
# "size":17.0,
# "blank":false
# },
# "legend_position":"none",
# "plot_title":{
# "face":"bold",
# "size":19.0,
# "blank":false
# },
# "plot_subtitle":{
# "size":18.0,
# "blank":false
# }
# },
# "ggsize":{
# "width":1000.0,
# "height":500.0
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "guide":"none",
# "discrete":true
# },{
# "name":"Categories\n(from largest to smallest median)",
# "aesthetic":"y",
# "expand":[0.05,0.05]
# },{
# "name":"Price (£)",
# "aesthetic":"x",
# "breaks":[0.0,2.5,5.0,7.5,10.0,12.5,15.0,17.5],
# "expand":[0.0,0.05],
# "format":"£ {.2f}"
# }],
# "layers":[{
# "geom":"linerange",
# "mapping":{
# },
# "tooltips":{
# "formats":[{
# "field":"@Q1",
# "format":"£ {.2f}"
# },{
# "field":"@Median",
# "format":"£ {.2f}"
# },{
# "field":"@Q3",
# "format":"£ {.2f}"
# }],
# "lines":["@category","[@Q1 -- @Median -- @Q3]"]
# },
# "data_meta":{
# },
# "size":1.0,
# "alpha":0.75,
# "orientation":"y",
# "data":{
# }
# },{
# "geom":"point",
# "mapping":{
# },
# "tooltips":{
# "formats":[{
# "field":"@Q1",
# "format":"£ {.2f}"
# },{
# "field":"@Median",
# "format":"£ {.2f}"
# },{
# "field":"@Q3",
# "format":"£ {.2f}"
# }],
# "lines":["@category","[@Q1 -- @Median -- @Q3]"]
# },
# "data_meta":{
# },
# "size":3.0,
# "stroke":1.0,
# "shape":21.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"1"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>
